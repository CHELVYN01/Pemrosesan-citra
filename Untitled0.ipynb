# %% [markdown]
# <a href="https://colab.research.google.com/github/CHELVYN01/Pemrosesan-citra/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

POPULATION_SIZE = 500


GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890, .-;:_!"#%&/()=?@${[]}'''


TARGET = "Aku cinta sanata dharma"


class Individual(object):

    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        global GENES
        gene = random.choice(GENES)
        return gene

    @classmethod

    def create_gnome(self):
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):

        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            prob = random.random()
            if prob < 0.45:
                child_chromosome.append(gp1)
            elif prob < 0.90:
                child_chromosome.append(gp2)
            else:
                child_chromosome.append(self.mutated_genes())
        return Individual(child_chromosome)

    def cal_fitness(self):
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness

def main(): #main program
    global POPULATION_SIZE

    generation = 1

    found = False

    population = []

    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:

        population = sorted(population, key = lambda x:x.fitness)

        if population[0].fitness <= 0:
            found = True
            break

        new_generation = []
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])

        s = int((90*POPULATION_SIZE)/100)

        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
                     "".join(population[0].chromosome),
                     population[0].fitness))

        generation += 1

        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
                     "".join(population[0].chromosome),
                     population[0].fitness))

if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: r)u";S(X@Bs%4b3A5}TMw#6	Fitness: 21
# Generation: 2	String: r)u";S(X@Bs%4b3A5}TMw#6	Fitness: 21
# Generation: 2	String: A(D(}
# ajx0M7uHpa(VhwDm}	Fitness: 19
# Generation: 3	String: A(D(}
# ajx0M7uHpa(VhwDm}	Fitness: 19
# Generation: 3	String: A(@8}
# no;fMamHZa(&hwum&	Fitness: 17
# Generation: 4	String: A(@8}
# no;fMamHZa(&hwum&	Fitness: 17
# Generation: 4	String: A(JRc
# no;N%afHZay&h[wm&	Fitness: 16
# Generation: 5	String: A(JRc
# no;N%afHZay&h[wm&	Fitness: 16
# Generation: 5	String: A{u ai@ax&saDaFa7$h6A
# T	Fitness: 14
# Generation: 6	String: A{u ai@ax&saDaFa7$h6A
# T	Fitness: 14
# Generation: 6	String: AM%wcLnt;0sanaqa(uh}Zm6	Fitness: 12
# Generation: 7	String: AM%wcLnt;0sanaqa(uh}Zm6	Fitness: 12
# Generation: 7	String: AMu cintp0s4n;Ja(uh}im6	Fitness: 11
# Generation: 8	String: AMu cintp0s4n;Ja(uh}im6	Fitness: 11
# Generation: 8	String: A(%jcinta0sanaqa uh5Zm%	Fitness: 9
# Generation: 9	String: A(%jcinta0sanaqa uh5Zm%	Fitness: 9
# Generation: 9	String: A
# u cin]aqsan@qa &h5rm7	Fitness: 8
# Generation: 10	String: A
# u cin]aqsan@qa &h5rm7	Fitness: 8
# Generation: 10	String: A6u cintA4saqaHa  harm6	Fitness: 7
# Generation: 11	String: A6u cintA4saqaHa  harm6	Fitness: 7
# Generation: 11	String: AIu }intaQsanyta(Bharma	Fitness: 6
# Generation: 12	String: AIu }intaQsanyta(Bharma	Fitness: 6
# Generation: 12	String: A(u Uinta0sanata(Bharma	Fitness: 5
# Generation: 13	String: A(u Uinta0sanata(Bharma	Fitness: 5
# Generation: 13	String: Avu cintaCsana7a dharma	Fitness: 3
# Generation: 14	String: Avu cintaCsana7a dharma	Fitness: 3
# Generation: 14	String: Avu cintaCsana7a dharma	Fitness: 3
# Generation: 15	String: Avu cintaCsana7a dharma	Fitness: 3
# Generation: 15	String: Abu cinta0sanata dharma	Fitness: 2
# Generation: 16	String: Abu cinta0sanata dharma	Fitness: 2
# Generation: 16	String: Abu cinta0sanata dharma	Fitness: 2
# Generation: 17	String: Abu cinta0sanata dharma	Fitness: 2
# Generation: 17	String: Abu cinta0sanata dharma	Fitness: 2
# Generation: 18	String: Abu cinta0sanata dharma	Fitness: 2

# %%
import random

POPULATION_SIZE = 1000


GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890, .-;:_!"#%&/()=?@${[]}'''


TARGET = "Aku cinta sanata dharma"


class Individual(object):

    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        global GENES
        gene = random.choice(GENES)
        return gene

    @classmethod

    def create_gnome(self):
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):

        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            prob = random.random()
            if prob < 0.45:
                child_chromosome.append(gp1)
            elif prob < 0.90:
                child_chromosome.append(gp2)
            else:
                child_chromosome.append(self.mutated_genes())
        return Individual(child_chromosome)

    def cal_fitness(self):
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness

def main(): #main program
    global POPULATION_SIZE

    generation = 1

    found = False

    population = []

    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:

        population = sorted(population, key = lambda x:x.fitness)

        if population[0].fitness <= 0:
            found = True
            break

        new_generation = []
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])

        s = int((90*POPULATION_SIZE)/100)

        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
                     "".join(population[0].chromosome),
                     population[0].fitness))

        generation += 1

        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
                     "".join(population[0].chromosome),
                     population[0].fitness))

if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: bDu_ydC!XL.?f@OoId322Z7	Fitness: 21
# Generation: 2	String: bDu_ydC!XL.?f@OoId322Z7	Fitness: 21
# Generation: 2	String: 0e7Ec@(ny9sak&6vW[h2RiZ	Fitness: 19
# Generation: 3	String: 0e7Ec@(ny9sak&6vW[h2RiZ	Fitness: 19
# Generation: 3	String: AJ99ci&tz)BCN9te,knIr7P	Fitness: 17
# Generation: 4	String: AJ99ci&tz)BCN9te,knIr7P	Fitness: 17
# Generation: 4	String: AktRcibtzRsa#5ta2znA$k6	Fitness: 14
# Generation: 5	String: AktRcibtzRsa#5ta2znA$k6	Fitness: 14
# Generation: 5	String: 8ku cvn-a]saK#ta[!h%4=a	Fitness: 11
# Generation: 6	String: 8ku cvn-a]saK#ta[!h%4=a	Fitness: 11
# Generation: 6	String: A#u c@nAaesanatf-dharO:	Fitness: 8
# Generation: 7	String: A#u c@nAaesanatf-dharO:	Fitness: 8
# Generation: 7	String: AkB cin0a6BanatN1dharma	Fitness: 6
# Generation: 8	String: AkB cin0a6BanatN1dharma	Fitness: 6
# Generation: 8	String: Aku cin"H sanatacdhaGka	Fitness: 5
# Generation: 9	String: Aku cin"H sanatacdhaGka	Fitness: 5
# Generation: 9	String: A#u cinta sanat-Rdharma	Fitness: 3
# Generation: 10	String: A#u cinta sanat-Rdharma	Fitness: 3
# Generation: 10	String: Aku cinta sana@a!dharma	Fitness: 2
# Generation: 11	String: Aku cinta sana@a!dharma	Fitness: 2
# Generation: 11	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 12	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 12	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 13	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 13	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 14	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 14	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 15	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 15	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 16	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 16	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 17	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 17	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 18	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 18	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 19	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 19	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 20	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 20	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 21	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 21	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 22	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 22	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 23	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 23	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 24	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 24	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 25	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 25	String: Aku cinta sanataRdharma	Fitness: 1
# Generation: 26	String: Aku cinta sanataRdharma	Fitness: 1
